# %% [markdown]
# ##### Let's use the human-in-the-loop middleware

# %%
from langchain.tools import tool


@tool
def send_email():
    """This tool send an email to our important clients"""
    
    print("sending an email")
    
    return "email sent"

@tool
def search_web():
    """This tool searches web for relevant information"""
    
    print("web searched. really.")
    
    return "searched. found."

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver
from langchain.agents.middleware import HumanInTheLoopMiddleware

store = InMemorySaver()

my_agent = create_agent(
    'ollama:gpt-oss:20b',
    checkpointer=store,
    tools=[send_email, search_web],
    middleware=[
        HumanInTheLoopMiddleware(
            interrupt_on={
                'send_email': True,
                'search_web': True
            }
        )
    ]
    
    )

# %%
config = {'thread_id': 1}

response = my_agent.invoke(
    {'messages': {'role': 'user', 'content': "call both tools"}},
    config
)

# %%
response
# Out:
# {'messages': [HumanMessage(content='call both tools', additional_kwargs={}, response_metadata={}, id='412d8948-ad16-4040-9b79-66d2a0bc5590'),
#   AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'gpt-oss:20b', 'created_at': '2025-12-24T08:20:05.215715Z', 'done': True, 'done_reason': 'stop', 'total_duration': 8132430792, 'load_duration': 4885077917, 'prompt_eval_count': 135, 'prompt_eval_duration': 1659739666, 'eval_count': 83, 'eval_duration': 1514747040, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, id='lc_run--019b4f71-8019-75b0-8663-5501d8049533-0', tool_calls=[{'name': 'search_web', 'args': {}, 'id': '40fef7e9-391c-463c-a5d0-9680857e0ffa', 'type': 'tool_call'}], usage_metadata={'input_tokens': 135, 'output_tokens': 83, 'total_tokens': 218})],
#  '__interrupt__': [Interrupt(value={'action_requests': [{'name': 'search_web', 'args': {}, 'description': 'Tool execution requires approval\n\nTool: search_web\nArgs: {}'}], 'review_configs': [{'action_name': 'search_web', 'allowed_decisions': ['approve', 'edit', 'reject']}]}, id='af0cb0514e2e799dcd29746de261261a')]}

# %%
from langgraph.types import Command

my_agent.invoke(Command(resume={"decisions": [{"type": "approve"}]}), config)
# Out:
# web searched. really.
# {'messages': [HumanMessage(content='call both tools', additional_kwargs={}, response_metadata={}, id='412d8948-ad16-4040-9b79-66d2a0bc5590'),
#   AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'gpt-oss:20b', 'created_at': '2025-12-24T08:20:05.215715Z', 'done': True, 'done_reason': 'stop', 'total_duration': 8132430792, 'load_duration': 4885077917, 'prompt_eval_count': 135, 'prompt_eval_duration': 1659739666, 'eval_count': 83, 'eval_duration': 1514747040, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, id='lc_run--019b4f71-8019-75b0-8663-5501d8049533-0', tool_calls=[{'name': 'search_web', 'args': {}, 'id': '40fef7e9-391c-463c-a5d0-9680857e0ffa', 'type': 'tool_call'}], usage_metadata={'input_tokens': 135, 'output_tokens': 83, 'total_tokens': 218}),
#   ToolMessage(content='searched. found.', name='search_web', id='589ab87f-c192-45d0-9d4a-ed271ce3d9d6', tool_call_id='40fef7e9-391c-463c-a5d0-9680857e0ffa'),
#   AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'gpt-oss:20b', 'created_at': '2025-12-24T08:20:56.940695Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1743270042, 'load_duration': 136536250, 'prompt_eval_count': 163, 'prompt_eval_duration': 324710375, 'eval_count': 68, 'eval_duration': 1237261670, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, id='lc_run--019b4f72-631c-7651-aff7-42da5c62da48-0', tool_calls=[{'name': 'send_email', 'args': {}, 'id': '1a873036-7dbf-4e84-8b81-9f02f3981747', 'type': 'tool_call'}], usage_metadata={'input_tokens': 163, 'output_tokens': 68, 'total_tokens': 231})],
#  '__interrupt__': [Interrupt(value={'action_requests': [{'name': 'send_email', 'args': {}, 'description': 'Tool execution requires approval\n\nTool: send_email\nArgs: {}'}], 'review_configs': [{'action_name': 'send_email', 'allowed_decisions': ['approve', 'edit', 'reject']}]}, id='0037820c60ed739c9f4526e3ca2ba6f4')]}

# %%
my_agent.invoke(Command(resume={"decisions": [{"type": "approve"}]}), config)
# Out:
# sending an email
# {'messages': [HumanMessage(content='call both tools', additional_kwargs={}, response_metadata={}, id='412d8948-ad16-4040-9b79-66d2a0bc5590'),
#   AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'gpt-oss:20b', 'created_at': '2025-12-24T08:20:05.215715Z', 'done': True, 'done_reason': 'stop', 'total_duration': 8132430792, 'load_duration': 4885077917, 'prompt_eval_count': 135, 'prompt_eval_duration': 1659739666, 'eval_count': 83, 'eval_duration': 1514747040, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, id='lc_run--019b4f71-8019-75b0-8663-5501d8049533-0', tool_calls=[{'name': 'search_web', 'args': {}, 'id': '40fef7e9-391c-463c-a5d0-9680857e0ffa', 'type': 'tool_call'}], usage_metadata={'input_tokens': 135, 'output_tokens': 83, 'total_tokens': 218}),
#   ToolMessage(content='searched. found.', name='search_web', id='589ab87f-c192-45d0-9d4a-ed271ce3d9d6', tool_call_id='40fef7e9-391c-463c-a5d0-9680857e0ffa'),
#   AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'gpt-oss:20b', 'created_at': '2025-12-24T08:20:56.940695Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1743270042, 'load_duration': 136536250, 'prompt_eval_count': 163, 'prompt_eval_duration': 324710375, 'eval_count': 68, 'eval_duration': 1237261670, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, id='lc_run--019b4f72-631c-7651-aff7-42da5c62da48-0', tool_calls=[{'name': 'send_email', 'args': {}, 'id': '1a873036-7dbf-4e84-8b81-9f02f3981747', 'type': 'tool_call'}], usage_metadata={'input_tokens': 163, 'output_tokens': 68, 'total_tokens': 231}),
#   ToolMessage(content='email sent', name='send_email', id='7db11381-bbe1-4ca0-91d1-95ed014b4e6a', tool_call_id='1a873036-7dbf-4e84-8b81-9f02f3981747'),
#   AIMessage(content='I’ve completed both tasks: the web search is finished, and an email has been sent to the important client. Let me know if you’d like anything else!', additional_kwargs={}, response_metadata={'model': 'gpt-oss:20b', 'created_at': '2025-12-24T08:21:20.423209Z', 'done': True, 'done_reason': 'stop', 'total_duration': 2528750792, 'load_duration': 128568959, 'prompt_eval_count': 189, 'prompt_eval_duration': 323486958, 'eval_count': 111, 'eval_duration': 2035080334, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, id='lc_run--019b4f72-bbc5-7f82-a977-2ce6ebe9f0ea-0', usage_metadata={'input_tokens': 189, 'output_tokens': 111, 'total_tokens': 300})]}
