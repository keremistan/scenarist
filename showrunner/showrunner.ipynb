# %% [markdown]
# This screenplay-writing program follows the architecture of a showrunner where there are 3 components.
# 1. **Retrieval**: loads and retrieves relevant documents from a vector store
# 2. **Showrunner**: memorises the relevant data such as theme, plot points, ending, summary of so-far written story
# 3. **Writer**: captures the user query, utilises retrieved document and considers the showrunner memory when writing a something new like a scene

# %%
from loader import ScreenplayLoader

sp_loader = ScreenplayLoader("../metropolis.pdf")

# %%
for i, doc in enumerate(sp_loader.lazy_load()):
    print("received doc:\n{}\n\n".format(doc))
    if i == 0:
        break
# Out:
# current index 0; start: 37; end: 202; len(matches): 257; len(whole_doc): 116684
# received doc:
# page_content='EXT. MANHATTAN - MIDDLE OF THE NIGHT
# Freezing wind shutters through the shadows. Relentless
# darkness. No sign of life, save for --
# The SOUND of determined footsteps.' metadata={'file_name': '../metropolis.pdf', 'scene_index': 1, 'scene_header': 'EXT. MANHATTAN - MIDDLE OF THE NIGHT\nF', 'type': 'scene'}

# %%
doc.page_content
# Out:
# 'EXT. MANHATTAN - MIDDLE OF THE NIGHT\nFreezing wind shutters through the shadows. Relentless\ndarkness. No sign of life, save for --\nThe SOUND of determined footsteps.'

# %%
from scene_analyzer import analyze_scene

response = analyze_scene(doc.page_content)
# Out:
# SceneAnalysis(happening='The scene establishes a nighttime Manhattan setting with a harsh, cold wind and complete darkness. The only auditory cue is the sound of determined footsteps, implying a lone, purposeful character moving through the city.', subtext_level_happening='The environment is hostile and silent, creating tension. The footsteps suggest urgency or a mission, but no visual action is shown, leaving the audience to imagine the character and purpose.', reader_reaction='Readers will sense isolation and suspense. The lack of visual detail may cause confusion about who is moving and why, potentially weakening engagement if not followed up quickly with action or dialogue.')
# SceneAnalysis(happening='The scene establishes a nighttime Manhattan setting with a harsh, cold wind and complete darkness. The only auditory cue is the sound of determined footsteps, implying a lone, purposeful character moving through the city.', subtext_level_happening='The environment is hostile and silent, creating tension. The footsteps suggest urgency or a mission, but no visual action is shown, leaving the audience to imagine the character and purpose.', reader_reaction='Readers will sense isolation and suspense. The lack of visual detail may cause confusion about who is moving and why, potentially weakening engagement if not followed up quickly with action or dialogue.')
